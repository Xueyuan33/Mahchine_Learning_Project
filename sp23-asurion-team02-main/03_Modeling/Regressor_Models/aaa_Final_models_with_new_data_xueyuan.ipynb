# %% [markdown]
# # method 1
#
# ### train data = iphone13 : days since release date: 57-160
# ### test data = iphone 14: days since release date: 59-143 , wmape=14.25%
# ### val_data=iphone 14 Feb, WMAPE: 26.26%
# ### model: ARIMA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from sklearn.model_selection import train_test_split

# Load the iPhone 12 dataset
df  = pd.read_csv('/Users/xueyuanli/Desktop/DS-team/time_series_ML_features_final.csv', parse_dates=['weeks_monday','month_year'])
df['weeks_since_release']=df['days_since_release_date'].floordiv(7)
print(df)
# Out:
#          phone_model weeks_monday  month  year month_year  \
# 0    apple iphone 11   2021-07-05      7  2021 2021-07-01
# 1     apple iphone x   2021-07-05      7  2021 2021-07-01
# 2    apple iphone 11   2021-07-12      7  2021 2021-07-01
# 3     apple iphone x   2021-07-12      7  2021 2021-07-01
# 4    apple iphone 11   2021-07-19      7  2021 2021-07-01
# ..               ...          ...    ...   ...        ...
# 321  apple iphone 14   2023-02-06      2  2023 2023-02-01
# 322  apple iphone 12   2023-02-06      2  2023 2023-02-01
# 323  apple iphone 13   2023-02-06      2  2023 2023-02-01
# 324  apple iphone 11   2023-02-06      2  2023 2023-02-01
# 325   apple iphone x   2023-02-06      2  2023 2023-02-01
#
#      days_since_release_date  claim  weeks_since_release
# 0                        654   2047                   93
# 1                       1340    555                  191
# 2                        661   1900                   94
# 3                       1347    496                  192
# 4                        668   1918                   95
# ..                       ...    ...                  ...
# 321                      143     61                   20
# 322                      836   1456                  119
# 323                      470   1191                   67
# 324                     1235   1307                  176
# 325                     1921    138                  274
#
# [326 rows x 8 columns]

# %%
df13=df[(df['phone_model']=='apple iphone 13')& (df['days_since_release_date']>=57) & (df['days_since_release_date']<=160)]
#df13=df[(df['phone_model']=='apple iphone 13')]
train_data=df13[['claim','weeks_monday']]
train_data = train_data.groupby(['weeks_monday'])['claim'].sum().reset_index()
train_data.set_index('weeks_monday', inplace=True)
x_train= train_data.drop('claim', axis=1)
y_train = train_data['claim']

df14=df[df['phone_model']=='apple iphone 14']
test_data=df14[['claim' ,'weeks_monday']]
test_data= test_data.groupby(['weeks_monday'])['claim'].sum().reset_index()
test_data.set_index('weeks_monday', inplace=True)
x_test= test_data.drop('claim', axis=1)
y_test = test_data['claim']

# %%
test_data
# Out:
#               claim
# weeks_monday
# 2022-11-14        9
# 2022-11-21       30
# 2022-11-28       23
# 2022-12-05       43
# 2022-12-12       32
# 2022-12-19       36
# 2022-12-26       44
# 2023-01-02       45
# 2023-01-09       59
# 2023-01-16       60
# 2023-01-23       57
# 2023-01-30       54
# 2023-02-06       61

# %%
model = ARIMA(train_data, order=(15,1,14))
model = model.fit()

print(model.summary())

predictions = model.predict(start=test_data.index[0],end=test_data.index[-1])

#forecast= model.forecast(start='2022-12-26', end='2023-03-06')

# Visualize the predictions
plt.plot(train_data, label='iphone13 Training Data')
plt.plot(test_data, label='iphone14 Testing Data')
plt.plot(predictions, label='iphone13 Predictions')
#plt.plot(forecast, label='iphone14 forecast')
plt.title('ARIMAX model for iphone14', fontsize=16, fontweight='bold')
plt.xticks(rotation=60)
plt.legend()
plt.show()
# Out:
# /Users/xueyuanli/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-MON will be used.
#   warnings.warn('No frequency information was'
# /Users/xueyuanli/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-MON will be used.
#   warnings.warn('No frequency information was'
# /Users/xueyuanli/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-MON will be used.
#   warnings.warn('No frequency information was'
# /Users/xueyuanli/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for ARMA and trend. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  claim   No. Observations:                   15
# Model:               ARIMA(15, 1, 14)   Log Likelihood                 -36.619
# Date:                Wed, 12 Apr 2023   AIC                            133.239
# Time:                        15:05:41   BIC                            152.411
# Sample:                    12-20-2021   HQIC                           131.464
#                          - 03-28-2022
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          2.7040     84.928      0.032      0.975    -163.751     169.159
# ar.L2         -3.8253     21.197     -0.180      0.857     -45.371      37.720
# ar.L3          2.8847     55.245      0.052      0.958    -105.394     111.163
# ar.L4          0.1499     49.026      0.003      0.998     -95.939      96.239
# ar.L5         -3.4026     73.091     -0.047      0.963    -146.659     139.854
# ar.L6          4.5014     35.416      0.127      0.899     -64.912      73.915
# ar.L7         -2.5386    110.122     -0.023      0.982    -218.374     213.297
# ar.L8         -1.2023     52.587     -0.023      0.982    -104.270     101.866
# ar.L9          4.3891     20.174      0.218      0.828     -35.152      43.930
# ar.L10        -4.9885     82.825     -0.060      0.952    -167.323     157.346
# ar.L11         2.8425     97.192      0.029      0.977    -187.650     193.335
# ar.L12         0.1577     48.345      0.003      0.997     -94.597      94.912
# ar.L13        -1.9516     26.492     -0.074      0.941     -53.875      49.972
# ar.L14         1.8459    134.405      0.014      0.989    -261.583     265.275
# ar.L15        -0.7830     48.460     -0.016      0.987     -95.763      94.197
# ma.L1         -0.9952     15.718     -0.063      0.950     -31.801      29.811
# ma.L2         -0.5961      6.631     -0.090      0.928     -13.592      12.400
# ma.L3          1.5479      5.108      0.303      0.762      -8.463      11.559
# ma.L4          0.4311     11.900      0.036      0.971     -22.892      23.754
# ma.L5         -1.7327     14.438     -0.120      0.904     -30.030      26.565
# ma.L6          0.4136     15.744      0.026      0.979     -30.444      31.271
# ma.L7          1.4825      9.833      0.151      0.880     -17.791      20.756
# ma.L8         -0.7446      0.756     -0.985      0.325      -2.226       0.737
# ma.L9         -0.6927      7.586     -0.091      0.927     -15.561      14.176
# ma.L10         1.0551     14.004      0.075      0.940     -26.393      28.503
# ma.L11         0.0793     19.549      0.004      0.997     -38.236      38.394
# ma.L12        -0.7317     17.192     -0.043      0.966     -34.427      32.964
# ma.L13         0.5851      7.293      0.080      0.936     -13.710      14.880
# ma.L14        -0.0214     19.983     -0.001      0.999     -39.188      39.146
# sigma2         0.0120      4.807      0.003      0.998      -9.409       9.433
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 0.25
# Prob(Q):                              1.00   Prob(JB):                         0.88
# Heteroskedasticity (H):               2.52   Skew:                             0.14
# Prob(H) (two-sided):                  0.33   Kurtosis:                         2.41
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 5.87e+20. Standard errors may be unstable.
# /Users/xueyuanli/opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/xueyuanli/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:132: FutureWarning: The 'freq' argument in Timestamp is deprecated and will be removed in a future version.
#   date_key = Timestamp(key, freq=base_index.freq)

# %%
def wmape(actual, forecast):
    # we take two series and calculate an output a wmape from it, not to be used in a grouping function

    # make a series called mape
    se_mape = abs(actual-forecast)/actual

    # get a float of the sum of the actual
    ft_actual_sum = actual.sum()

    # get a series of the multiple of the actual & the mape
    se_actual_prod_mape = actual * se_mape

    # summate the prod of the actual and the mape
    ft_actual_prod_mape_sum = se_actual_prod_mape.sum()

    # float: wmape of forecast
    ft_wmape_forecast = ft_actual_prod_mape_sum / ft_actual_sum

    # return a float
    return ft_wmape_forecast

from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(test_data['claim'], predictions)
print('MSE:', mse)

wmape=wmape(test_data['claim'],predictions)
print("WMAPE: {:.2%}".format(wmape))
# Out:
# MSE: 51.23837260318975
# WMAPE: 14.25%

# %%
new_val=pd.read_excel('/Users/xueyuanli/Desktop/DS-team/Asurion_data_additional-3.xlsx')
new_val=new_val[new_val['phone model']=='apple iphone 14']
new_val.drop('Unnamed: 0', axis=1)

val=new_val[['claim' ,'weeks_monday']]
val = val.groupby(['weeks_monday'])['claim'].sum().reset_index()
val= val.sort_values(by='weeks_monday')
val.set_index('weeks_monday', inplace=True)

x_val= val.drop('claim', axis=1)
y_val = val['claim']

# %%
y_val
# Out:
# weeks_monday
# 2023-02-06    61
# 2023-02-13    66
# 2023-02-20    68
# 2023-02-27    69
# Name: claim, dtype: int64

# %%
pred= model.predict(start=val.index[0],end=val.index[-1])
# Out:
# /Users/xueyuanli/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:132: FutureWarning: The 'freq' argument in Timestamp is deprecated and will be removed in a future version.
#   date_key = Timestamp(key, freq=base_index.freq)

# %%
pred
# Out:
# 2023-02-06    52.876046
# 2023-02-13    42.313550
# 2023-02-20    48.653289
# 2023-02-27    50.833406
# Freq: W-MON, Name: predicted_mean, dtype: float64

# %%
def wmape(actual, forecast):
    # we take two series and calculate an output a wmape from it, not to be used in a grouping function

    # make a series called mape
    se_mape = abs(actual-forecast)/actual

    # get a float of the sum of the actual
    ft_actual_sum = actual.sum()

    # get a series of the multiple of the actual & the mape
    se_actual_prod_mape = actual * se_mape

    # summate the prod of the actual and the mape
    ft_actual_prod_mape_sum = se_actual_prod_mape.sum()

    # float: wmape of forecast
    ft_wmape_forecast = ft_actual_prod_mape_sum / ft_actual_sum

    # return a float
    return ft_wmape_forecast

from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_val, pred)
print('MSE:', mse)

wmape=wmape(y_val,pred)
print("WMAPE: {:.2%}".format(wmape))
# Out:
# MSE: 332.84172167187876
# WMAPE: 26.26%

# %%
# Visualize the predictions
plt.plot(y_val, label='iphone14 Testing Data')
plt.plot(pred, label='iphone13 Predictions')
#plt.plot(forecast, label='iphone14 forecast')
plt.title('ARIMAX model for iphone14', fontsize=16, fontweight='bold')
plt.xticks(rotation=60)
plt.legend()
plt.show()

# %% [markdown]
# # method 1
#
# ### train data = iphone13 : days since release date: 57-160
# ### test data = iphone 14: with Feb
# ### model: ARIMA
# ### wmape= 18.52%

# %%
new_val=pd.read_excel('/Users/xueyuanli/Desktop/DS-team/Asurion_data_additional-3.xlsx')
new_val=new_val[new_val['phone model']=='apple iphone 14']
new_val.drop('Unnamed: 0', axis=1)

val=new_val[['claim' ,'weeks_monday']]
val = val.groupby(['weeks_monday'])['claim'].sum().reset_index()
val= val.sort_values(by='weeks_monday')
#val.set_index('weeks_monday', inplace=True)
val.drop(index=0, inplace=True)

# %%
df13=df[(df['phone_model']=='apple iphone 13')& (df['days_since_release_date']>=57) & (df['days_since_release_date']<=160)]
#df13=df[(df['phone_model']=='apple iphone 13')]
train_data=df13[['claim','weeks_monday']]
train_data = train_data.groupby(['weeks_monday'])['claim'].sum().reset_index()
train_data.set_index('weeks_monday', inplace=True)
x_train= train_data.drop('claim', axis=1)
y_train = train_data['claim']

df14=df[df['phone_model']=='apple iphone 14']
test=df14[['claim' ,'weeks_monday']]
#test_data=pd.merge(test, val, on=['weeks_monday', 'claim'])
test_data=pd.concat([test, val])
test_data.set_index('weeks_monday', inplace=True)

# %%
model = ARIMA(train_data, order=(15,1,14))
model = model.fit()

print(model.summary())

predictions = model.predict(start=test_data.index[0],end=test_data.index[-1])

#forecast= model.forecast(start='2022-12-26', end='2023-03-06')

# Visualize the predictions
plt.plot(train_data, label='iphone13 Training Data')
plt.plot(test_data, label='iphone14 Testing Data')
plt.plot(predictions, label='iphone13 Predictions')
#plt.plot(forecast, label='iphone14 forecast')
plt.title('ARIMAX model for iphone14', fontsize=16, fontweight='bold')
plt.xticks(rotation=60)
plt.legend()
plt.show()
# Out:
# /Users/xueyuanli/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-MON will be used.
#   warnings.warn('No frequency information was'
# /Users/xueyuanli/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-MON will be used.
#   warnings.warn('No frequency information was'
# /Users/xueyuanli/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency W-MON will be used.
#   warnings.warn('No frequency information was'
# /Users/xueyuanli/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for ARMA and trend. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  claim   No. Observations:                   15
# Model:               ARIMA(15, 1, 14)   Log Likelihood                 -36.619
# Date:                Wed, 12 Apr 2023   AIC                            133.239
# Time:                        15:05:50   BIC                            152.411
# Sample:                    12-20-2021   HQIC                           131.464
#                          - 03-28-2022
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          2.7040     84.928      0.032      0.975    -163.751     169.159
# ar.L2         -3.8253     21.197     -0.180      0.857     -45.371      37.720
# ar.L3          2.8847     55.245      0.052      0.958    -105.394     111.163
# ar.L4          0.1499     49.026      0.003      0.998     -95.939      96.239
# ar.L5         -3.4026     73.091     -0.047      0.963    -146.659     139.854
# ar.L6          4.5014     35.416      0.127      0.899     -64.912      73.915
# ar.L7         -2.5386    110.122     -0.023      0.982    -218.374     213.297
# ar.L8         -1.2023     52.587     -0.023      0.982    -104.270     101.866
# ar.L9          4.3891     20.174      0.218      0.828     -35.152      43.930
# ar.L10        -4.9885     82.825     -0.060      0.952    -167.323     157.346
# ar.L11         2.8425     97.192      0.029      0.977    -187.650     193.335
# ar.L12         0.1577     48.345      0.003      0.997     -94.597      94.912
# ar.L13        -1.9516     26.492     -0.074      0.941     -53.875      49.972
# ar.L14         1.8459    134.405      0.014      0.989    -261.583     265.275
# ar.L15        -0.7830     48.460     -0.016      0.987     -95.763      94.197
# ma.L1         -0.9952     15.718     -0.063      0.950     -31.801      29.811
# ma.L2         -0.5961      6.631     -0.090      0.928     -13.592      12.400
# ma.L3          1.5479      5.108      0.303      0.762      -8.463      11.559
# ma.L4          0.4311     11.900      0.036      0.971     -22.892      23.754
# ma.L5         -1.7327     14.438     -0.120      0.904     -30.030      26.565
# ma.L6          0.4136     15.744      0.026      0.979     -30.444      31.271
# ma.L7          1.4825      9.833      0.151      0.880     -17.791      20.756
# ma.L8         -0.7446      0.756     -0.985      0.325      -2.226       0.737
# ma.L9         -0.6927      7.586     -0.091      0.927     -15.561      14.176
# ma.L10         1.0551     14.004      0.075      0.940     -26.393      28.503
# ma.L11         0.0793     19.549      0.004      0.997     -38.236      38.394
# ma.L12        -0.7317     17.192     -0.043      0.966     -34.427      32.964
# ma.L13         0.5851      7.293      0.080      0.936     -13.710      14.880
# ma.L14        -0.0214     19.983     -0.001      0.999     -39.188      39.146
# sigma2         0.0120      4.807      0.003      0.998      -9.409       9.433
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 0.25
# Prob(Q):                              1.00   Prob(JB):                         0.88
# Heteroskedasticity (H):               2.52   Skew:                             0.14
# Prob(H) (two-sided):                  0.33   Kurtosis:                         2.41
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 5.87e+20. Standard errors may be unstable.
# /Users/xueyuanli/opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/xueyuanli/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:132: FutureWarning: The 'freq' argument in Timestamp is deprecated and will be removed in a future version.
#   date_key = Timestamp(key, freq=base_index.freq)

# %%
def wmape(actual, forecast):
    # we take two series and calculate an output a wmape from it, not to be used in a grouping function

    # make a series called mape
    se_mape = abs(actual-forecast)/actual

    # get a float of the sum of the actual
    ft_actual_sum = actual.sum()

    # get a series of the multiple of the actual & the mape
    se_actual_prod_mape = actual * se_mape

    # summate the prod of the actual and the mape
    ft_actual_prod_mape_sum = se_actual_prod_mape.sum()

    # float: wmape of forecast
    ft_wmape_forecast = ft_actual_prod_mape_sum / ft_actual_sum

    # return a float
    return ft_wmape_forecast

from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(test_data, predictions)
print('MSE:', mse)

wmape=wmape(test_data['claim'],predictions)
print("WMAPE: {:.2%}".format(wmape))
# Out:
# MSE: 120.71669354941223
# WMAPE: 18.52%

# %% [markdown]
# # method 2 -> shifted dataset
#
# ### train data: iphone 13: weeks_since_release<=20
# ### test data: all iphone 14( with Feb )
# ### best model:  TweedieRegressor
# ### wmape=10.12%, R-Squared=0.72

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from sklearn.model_selection import train_test_split

# Load the iPhone 12 dataset
df  = pd.read_csv('/Users/xueyuanli/Desktop/DS-team/time_series_ML_features_final.csv', parse_dates=['weeks_monday','month_year'])
df['weeks_since_release']=df['days_since_release_date'].floordiv(7)

# %%
new_val=pd.read_excel('/Users/xueyuanli/Desktop/DS-team/Asurion_data_additional-3.xlsx')
new_val=new_val[new_val['phone model']=='apple iphone 14']
new_val.drop('Unnamed: 0', axis=1)

val=new_val[['claim' ,'weeks_monday']]
val = val.groupby(['weeks_monday'])['claim'].sum().reset_index()
val= val.sort_values(by='weeks_monday')
#val.set_index('weeks_monday', inplace=True)
val.drop(index=0, inplace=True)

x_val= val.drop('claim', axis=1)
y_val = val['claim']

# %%
val
# Out:
#   weeks_monday  claim
# 1   2023-02-13     66
# 2   2023-02-20     68
# 3   2023-02-27     69

# %%
df13=df[(df['phone_model']=='apple iphone 13')& (df['weeks_since_release']<=20)]
train_data=df13[['claim','weeks_monday']]
train_data.set_index('weeks_monday', inplace=True)

df14=df[df['phone_model']=='apple iphone 14']
test=df14[['claim' ,'weeks_monday']]
#test_data=pd.merge(test, val, on=['weeks_monday', 'claim'])
test_data=pd.concat([test, val])
test_data.set_index('weeks_monday', inplace=True)

# %%
# Create lagged features for the claim variable
n_lags = 5 # Choose number of lags
for i in range(1, n_lags+1):
    train_data[f'claim_lag{i}'] = train_data['claim'].shift(i)
    test_data[f'claim_lag{i}'] = test_data['claim'].shift(i)

# Remove missing values from the data
train_data = train_data.dropna()
test_data = test_data.dropna()


# Split data into features and target
X_train = train_data.drop('claim', axis=1)
y_train = train_data['claim']
X_test = test_data.drop('claim', axis=1)
y_test = test_data['claim']


# Convert data frames to numpy arrays
X_train = X_train.to_numpy()
y_train = y_train.to_numpy()
X_test = X_test.to_numpy()
y_test = y_test.to_numpy()

# %% [markdown]
# Lagged features are created by shifting the value of a variable backwards in time by a certain number of time steps.
#
# The for loop iterates over the range from 1 to n_lags+1 (inclusive) and for each value i in that range, it creates a new column in both the train_data and test_data data frames. The name of each new column is 'claim_lag{i}', where {i} is the lag number. The value in each row of the new column is the value of the 'claim' variable from i time steps in the past.
#
# For example, 'claim_lag1' will contain the value of 'claim' from the previous time step, 'claim_lag2' will contain the value of 'claim' from two time steps in the past, and so on, up to 'claim_lag5' which will contain the value of 'claim' from five time steps in the past.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from lazypredict.Supervised import LazyRegressor
from sklearn.utils import shuffle
import numpy as np


reg = LazyRegressor(verbose=0, ignore_warnings=True, custom_metric = None)
# Train and test the models
models,predictions = reg.fit(X_train, X_test, y_train, y_test)

print(models)
# Out:
# 100%|██████████████████████████████████████████| 42/42 [00:00<00:00, 111.31it/s]
#                                Adjusted R-Squared  R-Squared   RMSE  \
# Model
# ElasticNet                                   0.43       0.72   5.41
# TweedieRegressor                             0.43       0.72   5.41
# RidgeCV                                      0.31       0.66   5.96
# ElasticNetCV                                 0.27       0.64   6.12
# Lasso                                        0.26       0.63   6.18
# HuberRegressor                               0.25       0.63   6.21
# LassoCV                                      0.24       0.62   6.26
# Lars                                         0.08       0.54   6.87
# LinearRegression                             0.08       0.54   6.87
# TransformedTargetRegressor                   0.08       0.54   6.87
# SGDRegressor                                -0.06       0.47   7.37
# Ridge                                       -0.09       0.46   7.48
# BayesianRidge                               -0.19       0.41   7.83
# OrthogonalMatchingPursuit                   -0.25       0.37   8.02
# LarsCV                                      -0.50       0.25   8.80
# LassoLarsCV                                 -0.50       0.25   8.80
# OrthogonalMatchingPursuitCV                 -1.24      -0.12  10.74
# PassiveAggressiveRegressor                  -1.46      -0.23  11.25
# LassoLarsIC                                 -2.73      -0.86  13.85
# KernelRidge                                 -3.29      -1.14  14.86
# LinearSVR                                   -4.65      -1.83  17.05
# LassoLars                                   -6.47      -2.74  19.61
# AdaBoostRegressor                          -12.45      -5.72  26.31
# BaggingRegressor                           -12.63      -5.82  26.49
# RANSACRegressor                            -12.96      -5.98  26.81
# GradientBoostingRegressor                  -12.98      -5.99  26.82
# ExtraTreesRegressor                        -13.11      -6.06  26.95
# ExtraTreeRegressor                         -13.40      -6.20  27.22
# DecisionTreeRegressor                      -13.41      -6.21  27.23
# RandomForestRegressor                      -13.58      -6.29  27.40
# XGBRegressor                               -13.60      -6.30  27.41
# KNeighborsRegressor                        -16.72      -7.86  30.19
# MLPRegressor                               -17.17      -8.09  30.58
# DummyRegressor                             -30.04     -14.52  39.97
# HistGradientBoostingRegressor              -30.04     -14.52  39.97
# LGBMRegressor                              -30.04     -14.52  39.97
# NuSVR                                      -30.25     -14.62  40.10
# SVR                                        -32.50     -15.75  41.52
# QuantileRegressor                          -34.10     -16.55  42.50
# GaussianProcessRegressor                   -62.23     -30.61  57.04
# GammaRegressor                            -463.85    -231.43 154.67
# PoissonRegressor                          -496.43    -247.71 160.00
#
#                                Time Taken
# Model
# ElasticNet                           0.00
# TweedieRegressor                     0.00
# RidgeCV                              0.00
# ElasticNetCV                         0.02
# Lasso                                0.00
# HuberRegressor                       0.01
# LassoCV                              0.02
# Lars                                 0.00
# LinearRegression                     0.00
# TransformedTargetRegressor           0.00
# SGDRegressor                         0.00
# Ridge                                0.00
# BayesianRidge                        0.00
# OrthogonalMatchingPursuit            0.00
# LarsCV                               0.01
# LassoLarsCV                          0.01
# OrthogonalMatchingPursuitCV          0.00
# PassiveAggressiveRegressor           0.00
# LassoLarsIC                          0.00
# KernelRidge                          0.00
# LinearSVR                            0.00
# LassoLars                            0.00
# AdaBoostRegressor                    0.04
# BaggingRegressor                     0.01
# RANSACRegressor                      0.01
# GradientBoostingRegressor            0.01
# ExtraTreesRegressor                  0.04
# ExtraTreeRegressor                   0.00
# DecisionTreeRegressor                0.00
# RandomForestRegressor                0.05
# XGBRegressor                         0.02
# KNeighborsRegressor                  0.00
# MLPRegressor                         0.03
# DummyRegressor                       0.00
# HistGradientBoostingRegressor        0.01
# LGBMRegressor                        0.01
# NuSVR                                0.00
# SVR                                  0.00
# QuantileRegressor                    0.01
# GaussianProcessRegressor             0.00
# GammaRegressor                       0.00
# PoissonRegressor                     0.00

# %%
from sklearn.linear_model import LinearRegression
from sklearn import linear_model
#model = linear_model.GammaRegressor()
model= linear_model.TweedieRegressor()
#model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
#forecast=model.forecast(steps=5)

# %%
def wmape(actual, forecast):
    # we take two series and calculate an output a wmape from it, not to be used in a grouping function

    # make a series called mape
    se_mape = abs(actual-forecast)/actual

    # get a float of the sum of the actual
    ft_actual_sum = actual.sum()

    # get a series of the multiple of the actual & the mape
    se_actual_prod_mape = actual * se_mape

    # summate the prod of the actual and the mape
    ft_actual_prod_mape_sum = se_actual_prod_mape.sum()

    # float: wmape of forecast
    ft_wmape_forecast = ft_actual_prod_mape_sum / ft_actual_sum

    # return a float
    return ft_wmape_forecast

from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test, y_pred)
print('MSE:', mse)

wmape=wmape(y_test,y_pred)
print("WMAPE: {:.2%}".format(wmape))
# Out:
# MSE: 46.217475615415
# WMAPE: 10.12%

# %%
# Visualize the predictions
plt.plot(train_data.index, y_train, label='iphone13 Training Data')
plt.plot(test_data.index, y_test, label='iphone14 Testing Data')
plt.plot(test_data.index, y_pred, label='iphone14 Predictions')
plt.title('TweedieRegressor model for iphone14', fontsize=16, fontweight='bold')
plt.xticks(rotation=60)
plt.legend()
plt.show()

# %% [markdown]
# # same method -> shifted dataset
#
# ### train data: all iphone 12
# ### test data: all iphone 14 (with Feb)
# ### best model: PassiveAggressiveRegressor model
# ### wmape=13.57%,  R-Squared=0.46%

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from sklearn.model_selection import train_test_split

# Load the iPhone 12 dataset
df  = pd.read_csv('/Users/xueyuanli/Desktop/DS-team/time_series_ML_features_final.csv', parse_dates=['weeks_monday','month_year'])
df['weeks_since_release']=df['days_since_release_date'].floordiv(7)

# %%
df13=df[(df['phone_model']=='apple iphone 12')]
train_data=df13[['claim','weeks_monday']]
train_data.set_index('weeks_monday', inplace=True)

df14=df[df['phone_model']=='apple iphone 14']
test=df14[['claim' ,'weeks_monday']]
#test_data=pd.merge(test, val, on=['weeks_monday', 'claim'])
test_data=pd.concat([test, val])
test_data.set_index('weeks_monday', inplace=True)

# %%
# Create lagged features for the claim variable
n_lags = 5 # Choose number of lags
for i in range(1, n_lags+1):
    train_data[f'claim_lag{i}'] = train_data['claim'].shift(i)
    test_data[f'claim_lag{i}'] = test_data['claim'].shift(i)

# Remove missing values from the data
train_data = train_data.dropna()
test_data = test_data.dropna()

# Split data into features and target
X_train = train_data.drop('claim', axis=1)
y_train = train_data['claim']
X_test = test_data.drop('claim', axis=1)
y_test = test_data['claim']

# Convert data frames to numpy arrays
X_train = X_train.to_numpy()
y_train = y_train.to_numpy()
X_test = X_test.to_numpy()
y_test = y_test.to_numpy()

# %%
train_data
# Out:
#               claim  claim_lag1  claim_lag2  claim_lag3  claim_lag4  \
# weeks_monday
# 2021-09-06      252      274.00      292.00      224.00      219.00
# 2021-09-13      266      252.00      274.00      292.00      224.00
# 2021-09-20      293      266.00      252.00      274.00      292.00
# 2021-09-27      324      293.00      266.00      252.00      274.00
# 2021-10-04      377      324.00      293.00      266.00      252.00
# ...             ...         ...         ...         ...         ...
# 2023-01-09     1558     1320.00     1047.00      963.00     1319.00
# 2023-01-16     1552     1558.00     1320.00     1047.00      963.00
# 2023-01-23     1407     1552.00     1558.00     1320.00     1047.00
# 2023-01-30     1171     1407.00     1552.00     1558.00     1320.00
# 2023-02-06     1456     1171.00     1407.00     1552.00     1558.00
#
#               claim_lag5
# weeks_monday
# 2021-09-06         69.00
# 2021-09-13        219.00
# 2021-09-20        224.00
# 2021-09-27        292.00
# 2021-10-04        274.00
# ...                  ...
# 2023-01-09       1279.00
# 2023-01-16       1319.00
# 2023-01-23        963.00
# 2023-01-30       1047.00
# 2023-02-06       1320.00
#
# [75 rows x 6 columns]

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from lazypredict.Supervised import LazyRegressor
from sklearn.utils import shuffle
import numpy as np


reg = LazyRegressor(verbose=0, ignore_warnings=True, custom_metric = None)
# Train and test the models
models,predictions = reg.fit(X_train, X_test, y_train, y_test)

print(models)
# Out:
# 100%|███████████████████████████████████████████| 42/42 [00:00<00:00, 68.86it/s]
#                                Adjusted R-Squared  R-Squared    RMSE  \
# Model
# PassiveAggressiveRegressor                  -0.09       0.46    7.47
# LinearSVR                                   -7.81      -3.41   21.30
# HuberRegressor                             -13.52      -6.26   27.34
# LinearRegression                           -27.27     -13.14   38.14
# TransformedTargetRegressor                 -27.27     -13.14   38.14
# Lars                                       -27.27     -13.14   38.14
# LassoLarsIC                                -27.27     -13.14   38.14
# Lasso                                      -30.63     -14.81   40.35
# MLPRegressor                               -30.68     -14.84   40.38
# BayesianRidge                              -31.85     -15.42   41.11
# SGDRegressor                               -33.23     -16.11   41.97
# LarsCV                                     -33.80     -16.40   42.32
# LassoLarsCV                                -33.80     -16.40   42.32
# RANSACRegressor                            -34.23     -16.61   42.58
# OrthogonalMatchingPursuit                  -35.29     -17.14   43.21
# OrthogonalMatchingPursuitCV                -35.29     -17.14   43.21
# Ridge                                      -37.57     -18.29   44.55
# RidgeCV                                    -37.57     -18.29   44.55
# LassoCV                                    -45.07     -22.03   48.69
# LassoLars                                  -60.48     -29.74   56.25
# ElasticNetCV                              -248.07    -123.53  113.22
# ElasticNet                                -328.73    -163.86  130.26
# TweedieRegressor                          -698.68    -348.84  189.76
# XGBRegressor                              -744.29    -371.65  195.84
# ExtraTreeRegressor                        -745.40    -372.20  195.99
# DecisionTreeRegressor                     -745.40    -372.20  195.99
# ExtraTreesRegressor                       -826.77    -412.89  206.40
# GradientBoostingRegressor                 -837.16    -418.08  207.69
# RandomForestRegressor                     -911.44    -455.22  216.69
# BaggingRegressor                          -956.31    -477.66  221.96
# KNeighborsRegressor                      -1178.13    -588.57  246.34
# PoissonRegressor                         -1194.75    -596.88  248.07
# AdaBoostRegressor                        -1351.22    -675.11  263.80
# GammaRegressor                           -1666.07    -832.54  292.90
# HistGradientBoostingRegressor            -2044.24   -1021.62  324.43
# LGBMRegressor                            -2169.76   -1084.38  334.24
# NuSVR                                   -12142.78   -6070.89  790.54
# DummyRegressor                          -12900.10   -6449.55  814.82
# SVR                                     -12942.10   -6470.55  816.14
# KernelRidge                             -13277.62   -6638.31  826.65
# QuantileRegressor                       -13314.16   -6656.58  827.79
# GaussianProcessRegressor               -226722.44 -113360.72 3415.82
#
#                                Time Taken
# Model
# PassiveAggressiveRegressor           0.00
# LinearSVR                            0.00
# HuberRegressor                       0.01
# LinearRegression                     0.00
# TransformedTargetRegressor           0.00
# Lars                                 0.00
# LassoLarsIC                          0.00
# Lasso                                0.00
# MLPRegressor                         0.04
# BayesianRidge                        0.01
# SGDRegressor                         0.01
# LarsCV                               0.01
# LassoLarsCV                          0.01
# RANSACRegressor                      0.00
# OrthogonalMatchingPursuit            0.00
# OrthogonalMatchingPursuitCV          0.00
# Ridge                                0.00
# RidgeCV                              0.00
# LassoCV                              0.02
# LassoLars                            0.00
# ElasticNetCV                         0.02
# ElasticNet                           0.00
# TweedieRegressor                     0.00
# XGBRegressor                         0.16
# ExtraTreeRegressor                   0.00
# DecisionTreeRegressor                0.00
# ExtraTreesRegressor                  0.05
# GradientBoostingRegressor            0.01
# RandomForestRegressor                0.06
# BaggingRegressor                     0.01
# KNeighborsRegressor                  0.00
# PoissonRegressor                     0.00
# AdaBoostRegressor                    0.03
# GammaRegressor                       0.00
# HistGradientBoostingRegressor        0.03
# LGBMRegressor                        0.01
# NuSVR                                0.00
# DummyRegressor                       0.00
# SVR                                  0.00
# KernelRidge                          0.00
# QuantileRegressor                    0.04
# GaussianProcessRegressor             0.00

# %%
from sklearn.linear_model import LinearRegression
from sklearn import linear_model
from sklearn.linear_model import PassiveAggressiveRegressor
#model = linear_model.GammaRegressor()
#model= linear_model.TweedieRegressor()
#model = LinearRegression()
model=PassiveAggressiveRegressor()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
#forecast=model.forecast(steps=5)

# %%
def wmape(actual, forecast):
    # we take two series and calculate an output a wmape from it, not to be used in a grouping function

    # make a series called mape
    se_mape = abs(actual-forecast)/actual

    # get a float of the sum of the actual
    ft_actual_sum = actual.sum()

    # get a series of the multiple of the actual & the mape
    se_actual_prod_mape = actual * se_mape

    # summate the prod of the actual and the mape
    ft_actual_prod_mape_sum = se_actual_prod_mape.sum()

    # float: wmape of forecast
    ft_wmape_forecast = ft_actual_prod_mape_sum / ft_actual_sum

    # return a float
    return ft_wmape_forecast

from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test, y_pred)
print('MSE:', mse)

wmape=wmape(y_test,y_pred)
print("WMAPE: {:.2%}".format(wmape))
# Out:
# MSE: 75.02118607523789
# WMAPE: 13.57%

# %%
# Visualize the predictions
plt.plot(test_data.index, y_test, label='iphone14 Testing Data')
plt.plot(test_data.index,y_pred, label='iphone14 Predictions')
plt.title('PassiveAggressiveRegressor model for iphone14', fontsize=16, fontweight='bold')
plt.xticks(rotation=60)
plt.legend()
plt.show()

# %%
# Visualize the predictions
plt.plot(train_data.index, y_train, label='iphone12 Training Data')
plt.plot(test_data.index, y_test, label='iphone14 Testing Data')
plt.plot(test_data.index,y_pred, label='iphone14 Predictions')
plt.title('PassiveAggressiveRegressor for iphone14', fontsize=16, fontweight='bold')
plt.xticks(rotation=60)
plt.legend()
plt.show()

# %% [markdown]
# # same method -> shifted dataset
#
# ## train data: all iphone 13
# ## test data: all iphone 14 (with Feb)
# ## best model: PassiveAggressiveRegressor
# ## wmape=12.38%, R-Squared =0.76

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from sklearn.model_selection import train_test_split

# Load the iPhone 12 dataset
df  = pd.read_csv('/Users/xueyuanli/Desktop/DS-team/time_series_ML_features_final.csv', parse_dates=['weeks_monday','month_year'])
df['weeks_since_release']=df['days_since_release_date'].floordiv(7)

# %%
df13=df[(df['phone_model']=='apple iphone 13')]
train_data=df13[['claim','weeks_monday']]
train_data.set_index('weeks_monday', inplace=True)

df14=df[df['phone_model']=='apple iphone 14']
test=df14[['claim' ,'weeks_monday']]
#test_data=pd.merge(test, val, on=['weeks_monday', 'claim'])
test_data=pd.concat([test, val])
test_data.set_index('weeks_monday', inplace=True)

# %%
# Create lagged features for the claim variable
n_lags = 5 # Choose number of lags
for i in range(1, n_lags+1):
    train_data[f'claim_lag{i}'] = train_data['claim'].shift(i)
    test_data[f'claim_lag{i}'] = test_data['claim'].shift(i)

# Remove missing values from the data
train_data = train_data.dropna()
test_data = test_data.dropna()

# Split data into features and target
X_train = train_data.drop('claim', axis=1)
y_train = train_data['claim']
X_test = test_data.drop('claim', axis=1)
y_test = test_data['claim']

# Convert data frames to numpy arrays
X_train = X_train.to_numpy()
y_train = y_train.to_numpy()
X_test = X_test.to_numpy()
y_test = y_test.to_numpy()

# %%
train_data
# Out:
#               claim  claim_lag1  claim_lag2  claim_lag3  claim_lag4  \
# weeks_monday
# 2021-12-20        6       10.00        2.00        6.00        3.00
# 2021-12-27       15        6.00       10.00        2.00        6.00
# 2022-01-03        7       15.00        6.00       10.00        2.00
# 2022-01-10       13        7.00       15.00        6.00       10.00
# 2022-01-17       10       13.00        7.00       15.00        6.00
# 2022-01-24       11       10.00       13.00        7.00       15.00
# 2022-01-31       12       11.00       10.00       13.00        7.00
# 2022-02-07       15       12.00       11.00       10.00       13.00
# 2022-02-14       23       15.00       12.00       11.00       10.00
# 2022-02-21       19       23.00       15.00       12.00       11.00
# 2022-02-28       35       19.00       23.00       15.00       12.00
# 2022-03-07       32       35.00       19.00       23.00       15.00
# 2022-03-14       31       32.00       35.00       19.00       23.00
# 2022-03-21       24       31.00       32.00       35.00       19.00
# 2022-03-28       43       24.00       31.00       32.00       35.00
# 2022-04-04       65       43.00       24.00       31.00       32.00
# 2022-04-11       56       65.00       43.00       24.00       31.00
# 2022-04-18      215       56.00       65.00       43.00       24.00
# 2022-04-25      206      215.00       56.00       65.00       43.00
# 2022-05-02      221      206.00      215.00       56.00       65.00
# 2022-05-09      265      221.00      206.00      215.00       56.00
# 2022-05-16      265      265.00      221.00      206.00      215.00
# 2022-05-23      327      265.00      265.00      221.00      206.00
# 2022-05-30      303      327.00      265.00      265.00      221.00
# 2022-06-06      337      303.00      327.00      265.00      265.00
# 2022-06-13      355      337.00      303.00      327.00      265.00
# 2022-06-20      411      355.00      337.00      303.00      327.00
# 2022-06-27      422      411.00      355.00      337.00      303.00
# 2022-07-04      432      422.00      411.00      355.00      337.00
# 2022-07-11      434      432.00      422.00      411.00      355.00
# 2022-07-18      509      434.00      432.00      422.00      411.00
# 2022-07-25      507      509.00      434.00      432.00      422.00
# 2022-08-01      561      507.00      509.00      434.00      432.00
# 2022-08-08      675      561.00      507.00      509.00      434.00
# 2022-08-15      648      675.00      561.00      507.00      509.00
# 2022-08-22      592      648.00      675.00      561.00      507.00
# 2022-08-29      680      592.00      648.00      675.00      561.00
# 2022-09-05      688      680.00      592.00      648.00      675.00
# 2022-09-12      640      688.00      680.00      592.00      648.00
# 2022-09-19      596      640.00      688.00      680.00      592.00
# 2022-09-26      600      596.00      640.00      688.00      680.00
# 2022-10-03      655      600.00      596.00      640.00      688.00
# 2022-10-10      780      655.00      600.00      596.00      640.00
# 2022-10-17      709      780.00      655.00      600.00      596.00
# 2022-10-24      803      709.00      780.00      655.00      600.00
# 2022-10-31      778      803.00      709.00      780.00      655.00
# 2022-11-07      741      778.00      803.00      709.00      780.00
# 2022-11-14      708      741.00      778.00      803.00      709.00
# 2022-11-21      786      708.00      741.00      778.00      803.00
# 2022-11-28      776      786.00      708.00      741.00      778.00
# 2022-12-05      700      776.00      786.00      708.00      741.00
# 2022-12-12      664      700.00      776.00      786.00      708.00
# 2022-12-19      397      664.00      700.00      776.00      786.00
# 2022-12-26      411      397.00      664.00      700.00      776.00
# 2023-01-02      844      411.00      397.00      664.00      700.00
# 2023-01-09      815      844.00      411.00      397.00      664.00
# 2023-01-16      999      815.00      844.00      411.00      397.00
# 2023-01-23     1191      999.00      815.00      844.00      411.00
# 2023-01-30      909     1191.00      999.00      815.00      844.00
# 2023-02-06     1191      909.00     1191.00      999.00      815.00
#
#               claim_lag5
# weeks_monday
# 2021-12-20          2.00
# 2021-12-27          3.00
# 2022-01-03          6.00
# 2022-01-10          2.00
# 2022-01-17         10.00
# 2022-01-24          6.00
# 2022-01-31         15.00
# 2022-02-07          7.00
# 2022-02-14         13.00
# 2022-02-21         10.00
# 2022-02-28         11.00
# 2022-03-07         12.00
# 2022-03-14         15.00
# 2022-03-21         23.00
# 2022-03-28         19.00
# 2022-04-04         35.00
# 2022-04-11         32.00
# 2022-04-18         31.00
# 2022-04-25         24.00
# 2022-05-02         43.00
# 2022-05-09         65.00
# 2022-05-16         56.00
# 2022-05-23        215.00
# 2022-05-30        206.00
# 2022-06-06        221.00
# 2022-06-13        265.00
# 2022-06-20        265.00
# 2022-06-27        327.00
# 2022-07-04        303.00
# 2022-07-11        337.00
# 2022-07-18        355.00
# 2022-07-25        411.00
# 2022-08-01        422.00
# 2022-08-08        432.00
# 2022-08-15        434.00
# 2022-08-22        509.00
# 2022-08-29        507.00
# 2022-09-05        561.00
# 2022-09-12        675.00
# 2022-09-19        648.00
# 2022-09-26        592.00
# 2022-10-03        680.00
# 2022-10-10        688.00
# 2022-10-17        640.00
# 2022-10-24        596.00
# 2022-10-31        600.00
# 2022-11-07        655.00
# 2022-11-14        780.00
# 2022-11-21        709.00
# 2022-11-28        803.00
# 2022-12-05        778.00
# 2022-12-12        741.00
# 2022-12-19        708.00
# 2022-12-26        786.00
# 2023-01-02        776.00
# 2023-01-09        700.00
# 2023-01-16        664.00
# 2023-01-23        397.00
# 2023-01-30        411.00
# 2023-02-06        844.00

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from lazypredict.Supervised import LazyRegressor
from sklearn.utils import shuffle
import numpy as np


reg = LazyRegressor(verbose=0, ignore_warnings=True, custom_metric = None)
# Train and test the models
models,predictions = reg.fit(X_train, X_test, y_train, y_test)

print(models)
# Out:
# 100%|███████████████████████████████████████████| 42/42 [00:00<00:00, 70.72it/s]
#                                Adjusted R-Squared  R-Squared   RMSE  \
# Model
# PassiveAggressiveRegressor                   0.51       0.76   5.02
# HuberRegressor                              -0.63       0.18   9.17
# HistGradientBoostingRegressor               -1.74      -0.37  11.88
# KNeighborsRegressor                         -4.44      -1.72  16.74
# LGBMRegressor                               -5.17      -2.08  17.82
# TransformedTargetRegressor                  -5.40      -2.20  18.14
# LinearRegression                            -5.40      -2.20  18.14
# Lars                                        -5.40      -2.20  18.14
# OrthogonalMatchingPursuitCV                 -5.50      -2.25  18.29
# LassoLarsIC                                 -5.59      -2.29  18.41
# RidgeCV                                     -5.65      -2.33  18.50
# BayesianRidge                               -6.01      -2.51  19.00
# Lasso                                       -6.03      -2.52  19.02
# SGDRegressor                                -6.35      -2.68  19.45
# Ridge                                       -8.10      -3.55  21.64
# OrthogonalMatchingPursuit                   -8.54      -3.77  22.16
# LassoCV                                    -10.04      -4.52  23.83
# LassoLarsCV                                -11.04      -5.02  24.89
# LarsCV                                     -11.04      -5.02  24.89
# LassoLars                                  -13.47      -6.23  27.29
# RANSACRegressor                            -13.56      -6.28  27.37
# GaussianProcessRegressor                   -19.69      -9.34  32.63
# LinearSVR                                  -34.75     -16.87  42.89
# GammaRegressor                             -45.11     -22.06  48.71
# ElasticNetCV                               -49.05     -24.03  50.75
# MLPRegressor                               -50.96     -24.98  51.71
# PoissonRegressor                           -70.94     -34.97  60.84
# ElasticNet                                 -77.47     -38.23  63.55
# RandomForestRegressor                     -157.26     -78.13  90.25
# TweedieRegressor                          -161.85     -80.43  91.55
# ExtraTreesRegressor                       -181.76     -90.38  96.98
# BaggingRegressor                          -212.37    -105.68 104.79
# XGBRegressor                              -224.31    -111.66 107.68
# GradientBoostingRegressor                 -273.13    -136.07 118.78
# AdaBoostRegressor                         -293.76    -146.38 123.16
# DecisionTreeRegressor                     -346.73    -172.87 133.77
# ExtraTreeRegressor                        -362.87    -180.94 136.84
# NuSVR                                    -1780.79    -889.89 302.81
# SVR                                      -2357.10   -1178.05 348.36
# QuantileRegressor                        -2700.45   -1349.72 372.86
# DummyRegressor                           -2803.62   -1401.31 379.91
# KernelRidge                              -3346.73   -1672.86 415.07
#
#                                Time Taken
# Model
# PassiveAggressiveRegressor           0.00
# HuberRegressor                       0.01
# HistGradientBoostingRegressor        0.03
# KNeighborsRegressor                  0.00
# LGBMRegressor                        0.05
# TransformedTargetRegressor           0.00
# LinearRegression                     0.00
# Lars                                 0.00
# OrthogonalMatchingPursuitCV          0.00
# LassoLarsIC                          0.00
# RidgeCV                              0.00
# BayesianRidge                        0.01
# Lasso                                0.00
# SGDRegressor                         0.01
# Ridge                                0.00
# OrthogonalMatchingPursuit            0.00
# LassoCV                              0.02
# LassoLarsCV                          0.01
# LarsCV                               0.01
# LassoLars                            0.00
# RANSACRegressor                      0.00
# GaussianProcessRegressor             0.00
# LinearSVR                            0.00
# GammaRegressor                       0.00
# ElasticNetCV                         0.02
# MLPRegressor                         0.04
# PoissonRegressor                     0.00
# ElasticNet                           0.00
# RandomForestRegressor                0.06
# TweedieRegressor                     0.00
# ExtraTreesRegressor                  0.04
# BaggingRegressor                     0.01
# XGBRegressor                         0.14
# GradientBoostingRegressor            0.01
# AdaBoostRegressor                    0.04
# DecisionTreeRegressor                0.00
# ExtraTreeRegressor                   0.00
# NuSVR                                0.00
# SVR                                  0.00
# QuantileRegressor                    0.02
# DummyRegressor                       0.00
# KernelRidge                          0.00

# %%
from sklearn.linear_model import LinearRegression
from sklearn import linear_model
from sklearn.linear_model import PassiveAggressiveRegressor
#model = linear_model.GammaRegressor()
#model= linear_model.TweedieRegressor()
#model = LinearRegression()
model=PassiveAggressiveRegressor()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
#forecast=model.forecast(steps=5)

# %%
def wmape(actual, forecast):
    # we take two series and calculate an output a wmape from it, not to be used in a grouping function

    # make a series called mape
    se_mape = abs(actual-forecast)/actual

    # get a float of the sum of the actual
    ft_actual_sum = actual.sum()

    # get a series of the multiple of the actual & the mape
    se_actual_prod_mape = actual * se_mape

    # summate the prod of the actual and the mape
    ft_actual_prod_mape_sum = se_actual_prod_mape.sum()

    # float: wmape of forecast
    ft_wmape_forecast = ft_actual_prod_mape_sum / ft_actual_sum

    # return a float
    return ft_wmape_forecast

from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test, y_pred)
print('MSE:', mse)

wmape=wmape(y_test,y_pred)
print("WMAPE: {:.2%}".format(wmape))
# Out:
# MSE: 67.03224053249696
# WMAPE: 12.38%

# %%
# Visualize the predictions
plt.plot(train_data.index, y_train, label='iphone13 Training Data')
plt.plot(test_data.index, y_test, label='iphone14 Testing Data')
plt.plot(test_data.index,y_pred, label='iphone14 Predictions')
plt.title('PassiveAggressiveRegressor for iphone14', fontsize=16, fontweight='bold')
plt.xticks(rotation=60)
plt.legend()
plt.show()

# %%
plt.plot(test_data.index, y_test, label='iphone14 Testing Data')
plt.plot(test_data.index,y_pred, label='iphone14 Predictions')
plt.title('PassiveAggressiveRegressor for iphone14', fontsize=16, fontweight='bold')
plt.xticks(rotation=60)
plt.legend()
plt.show()
